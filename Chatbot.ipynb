# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

nltk.download('punkt')
nltk.download('wordnet')
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/intents.json').read()
intents = json.loads(data_file)
for intent in intents['intents']:
 for pattern in intent['patterns']:
  #tokenize each word
  w = nltk.word_tokenize(pattern)
  words.extend(w)
  #add documents in the corpus
  documents.append((w, intent['tag']))
  # add to our classes list
  if intent['tag'] not in classes:
      classes.append(intent['tag'])
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
 # initialize our bag of words
 bag = []
 # list of tokenized words for the pattern
 pattern_words = doc[0]
 # lemmatize each word - create base word, in attempt to represent related words
 pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
 # create our bag of words array with 1, if word match found in current pattern
 for w in words:
  bag.append(1) if w in pattern_words else bag.append(0)

 # output is a '0' for each tag and '1' for current tag (for each pattern)
 output_row = list(output_empty)
 output_row[classes.index(doc[1])] = 1

 training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3r output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5,
verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/200
# 10/10 [==============================] - 14s 2ms/step - loss: 2.2606 - accuracy: 0.0765
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1698 - accuracy: 0.1044
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1256 - accuracy: 0.3564
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0957 - accuracy: 0.1806
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0145 - accuracy: 0.3330
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8618 - accuracy: 0.4801
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8753 - accuracy: 0.5917
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7194 - accuracy: 0.6393
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6316 - accuracy: 0.6545
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5349 - accuracy: 0.4814
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4133 - accuracy: 0.5688
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0463 - accuracy: 0.7396
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9664 - accuracy: 0.7102
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8953 - accuracy: 0.7494
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9177 - accuracy: 0.7124
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7431 - accuracy: 0.8553
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9298 - accuracy: 0.7466
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7825 - accuracy: 0.7644
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5207 - accuracy: 0.9360
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.8173
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.8642
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.9157
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5466 - accuracy: 0.8544
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.8045
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5028 - accuracy: 0.7589
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3093 - accuracy: 0.9038
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3544 - accuracy: 0.9199
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2964 - accuracy: 0.9379
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.9280
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.9258
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2395 - accuracy: 0.9176
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2852 - accuracy: 0.8812
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2111 - accuracy: 0.9780
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8121
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 1.0000
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1879 - accuracy: 0.9570
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0929 - accuracy: 0.9880
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3412 - accuracy: 0.8582
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1851 - accuracy: 0.9127
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9718
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1358 - accuracy: 0.9892
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.9561
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2158 - accuracy: 0.9165
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1825 - accuracy: 0.9561
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1703 - accuracy: 0.9447
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1374 - accuracy: 0.9780
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.9336
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9720
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1409 - accuracy: 0.9720
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1135 - accuracy: 0.9718
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1473 - accuracy: 0.9547
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9780
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9273
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9862
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9629
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9780
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 0.9826
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2238 - accuracy: 0.9447
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1206 - accuracy: 0.9273
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 0.9447
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 0.9447
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9826
# Epoch 76/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0960 - accuracy: 0.9309
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9941
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9862
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9862
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9892
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9862
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9447
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9629
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9780
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9826
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 0.9780
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9961
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9803
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1827 - accuracy: 0.9447
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9780
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9365
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9545
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9561
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9941
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9918
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9892
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9439
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9892
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9447
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9826
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9720
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9854
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9570
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9780
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9755
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0829 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.9862
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9918
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0551 - accuracy: 0.9918
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9447
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9718
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9629
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9941
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9447
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9918
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 0.9780
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9720
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9720
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9892
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.9862
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# model created

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list


def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-19-838177d36a2d> in <module>()
#      19         ChatLog.yview(END)
#      20 display1 = "HELLO CHAT"
# ---> 21 base = Tk(display1)
#      22 base.title("Hello")
#      23 base.geometry("400x500")
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: couldn't connect to display "HELLO CHAT"

# %% [markdown]
# # New Section
